# %%
# Lê a linha de lançamentos do stdin
entrada = input().strip()

# Inicialize o saldo do dia
saldo = 0.0

# Divide os lançamentos pela vírgula
lancamentos = entrada.split(',')

def calcular_lucro(lancamentos):
    valor_receita = 0
    valor_despesa = 0
    for lancamento in lancamentos:
        tipo, valor = lancamento.strip().split()
        valor = float(valor)
        if tipo == "R":
            valor_receita += valor
        else:
            valor_despesa += valor
    return valor_receita - valor_despesa

        # TODO: Atualize o saldo conforme o tipo de lançamento ('R' soma, 'D' subtrai)
    

# Imprima o saldo final com duas casas decimais
print(f"{calcular_lucro(lancamentos):.2f}")
# Out:
# 70.00

# %%
# Leitura da linha de identificadores de transações
entrada = input()

# TODO: Crie uma lista com as transações sem duplicatas, mantendo a ordem da primeira ocorrência

lista = entrada.split(' ')

transacoes_unicas = set()

for i in lista:
  transacoes_unicas.add(i)

# Dica: Percorra cada transação e adicione à lista apenas se ainda não estiver presente

print(' '.join(transacoes_unicas))  # Descomente após implementar a lógica
# Out:
# TX1001 TX1002 TX1003

# %%
print(teste)
# Out:
# None
